# %%
import pandas as pd

df = pd.read_excel("/Users/khoadong/Downloads/sampled_Weekly data_Đối thủ SHB_09.03-15.03.2026 Copy.xlsx")

# %%
df['PublishedDate'] = pd.to_datetime(df['PublishedDate'])
filtered_df = df[(df['Topic'] == 'SHB') & 
                 (df['PublishedDate'] > '2026-03-09') & 
                 (df['PublishedDate'] <= '2026-03-16')]
filtered_df
# Out:
#                                             Id                   TopicId  \
# 37065        1660052842830685_1660061002829869  5683bd53f9876f7e0db58a7b
# 37066         480241356497738_1620992282422634  5683bd53f9876f7e0db58a7b
# 37067         345386737630642_1662533972582572  5683bd53f9876f7e0db58a7b
# 37068         657547431784473_1987901628749040  5683bd53f9876f7e0db58a7b
# 37069         657547431784473_1987208508818352  5683bd53f9876f7e0db58a7b
# ...                                        ...                       ...
# 65161       585166751355232_122166962066817463  5683bd53f9876f7e0db58a7b
# 65162        61578155037107_122174085962938501  5683bd53f9876f7e0db58a7b
# 65163  6947858058232644609_7615532030549298440  5683bd53f9876f7e0db58a7b
# 65164        1025979920767106_1492873025740179  5683bd53f9876f7e0db58a7b
# 65165       761438953721910_122126918733022519  5683bd53f9876f7e0db58a7b
#
#       Topic                                              Title  \
# ...
